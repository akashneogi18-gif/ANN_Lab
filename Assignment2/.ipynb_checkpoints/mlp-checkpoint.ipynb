# %%
import pandas as pd, numpy as np
df = pd.read_csv('hr_processed.csv')
df.sample(5)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 11937            0.001418         1.326621       -0.690216
# 7507             0.250319         1.504837        0.169489
# 2778            -0.620833         1.683052       -0.690216
# 9075             0.457736         1.445431        0.169489
# 9299             1.411856        -0.811965       -0.690216
#
#        average_monthly_hours  time_spend_company  Work_accident  left  \
# 11937              -0.584363                 0.0              0     0
# 7507                1.303755                 0.0              0     0
# 2778                0.318650                -1.0              0     0
# 9075               -0.071287                 0.0              0     0
# 9299               -0.009718                -1.0              0     0
#
#        promotion_last_5years  salary  5year_experience  ...  sales_IT  \
# 11937                      0     1.0                 0  ...       0.0
# 7507                       0     0.0                 0  ...       0.0
# 2778                       0     0.0                 0  ...       0.0
# 9075                       0     2.0                 0  ...       0.0
# 9299                       0     1.0                 0  ...       0.0
#
#        sales_RandD  sales_accounting  sales_hr  sales_management  \
# 11937          0.0               0.0       0.0               1.0
# 7507           0.0               0.0       0.0               0.0
# 2778           0.0               0.0       0.0               0.0
# 9075           0.0               1.0       0.0               0.0
# 9299           1.0               0.0       0.0               0.0
#
#        sales_marketing  sales_product_mng  sales_sales  sales_support  \
# 11937              0.0                0.0          0.0            0.0
# 7507               0.0                0.0          0.0            0.0
# 2778               0.0                0.0          0.0            0.0
# 9075               0.0                0.0          0.0            0.0
# 9299               0.0                0.0          0.0            0.0
#
#        sales_technical
# 11937              0.0
# 7507               1.0
# 2778               1.0
# 9075               0.0
# 9299               0.0
#
# [5 rows x 29 columns]

# %%
df['left'].value_counts()
# Out:
# left
# 0    10000
# 1     1991
# Name: count, dtype: int64

# %% [markdown]
# - dataset is imbalanced

# %%
X = df.drop('left', axis=1).values
y = df['left'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=18)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=18)
X_train, y_train = sm.fit_resample(X_train, y_train)
# Out:
# C:\Users\Akash\anaconda3\envs\myenv\Lib\site-packages\joblib\externals\loky\backend\context.py:150: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\Akash\anaconda3\envs\myenv\Lib\site-packages\joblib\externals\loky\backend\context.py", line 227, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\Akash\anaconda3\envs\myenv\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Akash\anaconda3\envs\myenv\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\Akash\anaconda3\envs\myenv\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^

# %%
pd.Series(y_train).value_counts()
# Out:
# 0    7991
# 1    7991
# Name: count, dtype: int64

# %% [markdown]
# - small dataset(<5k) : tolerance 0.0001
# - medium dataset(~12k) : tolerance 0.0001 or 0.00001
# - large dataset(>100k) : tolerance 0.001

# %%
import nbimporter
from PerformanceMetrics import PerformanceMetrics

# %%
df.shape
# Out:
# (11991, 29)

# %% [markdown]
# - class sklearn.neural_network.MLPClassifier(hidden_layer_sizes=(100,), activation='relu', *, solver='adam', alpha=0.0001, batch_size='auto', learning_rate='constant', learning_rate_init=0.001, power_t=0.5, max_iter=200, shuffle=True, random_state=None, tol=0.0001, verbose=False, warm_start=False, momentum=0.9, nesterovs_momentum=True, early_stopping=False, validation_fraction=0.1, beta_1=0.9, beta_2=0.999, epsilon=1e-08, n_iter_no_change=10, max_fun=15000)

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=(60,30), activation='relu', solver='adam', learning_rate='adaptive',
                    learning_rate_init=0.001, max_iter=200, random_state=18, tol=0.00001,
                    verbose=True, early_stopping=True, validation_fraction=0.1)

# %%
mlp.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 0.49246236
# Validation score: 0.931207
# Iteration 2, loss = 0.20880912
# Validation score: 0.941213
# Iteration 3, loss = 0.16190044
# Validation score: 0.948093
# Iteration 4, loss = 0.14475225
# Validation score: 0.949969
# Iteration 5, loss = 0.13325983
# Validation score: 0.951220
# Iteration 6, loss = 0.12528944
# Validation score: 0.952470
# Iteration 7, loss = 0.11996718
# Validation score: 0.954972
# Iteration 8, loss = 0.11476846
# Validation score: 0.956223
# Iteration 9, loss = 0.11198108
# Validation score: 0.957473
# Iteration 10, loss = 0.10747826
# Validation score: 0.958724
# Iteration 11, loss = 0.10406809
# Validation score: 0.958724
# Iteration 12, loss = 0.10170168
# Validation score: 0.959975
# Iteration 13, loss = 0.09822243
# Validation score: 0.961226
# Iteration 14, loss = 0.09620876
# Validation score: 0.960600
# Iteration 15, loss = 0.09419262
# Validation score: 0.961851
# Iteration 16, loss = 0.09097652
# Validation score: 0.963102
# Iteration 17, loss = 0.08873410
# Validation score: 0.964978
# Iteration 18, loss = 0.08705733
# Validation score: 0.966229
# Iteration 19, loss = 0.08422978
# Validation score: 0.964978
# Iteration 20, loss = 0.08259079
# Validation score: 0.966854
# Iteration 21, loss = 0.08042030
# Validation score: 0.967480
# Iteration 22, loss = 0.07902522
# Validation score: 0.969981
# Iteration 23, loss = 0.07700334
# Validation score: 0.970607
# Iteration 24, loss = 0.07543800
# Validation score: 0.968105
# Iteration 25, loss = 0.07466745
# Validation score: 0.970607
# Iteration 26, loss = 0.07232666
# Validation score: 0.968730
# Iteration 27, loss = 0.07143535
# Validation score: 0.972483
# Iteration 28, loss = 0.06963542
# Validation score: 0.969981
# Iteration 29, loss = 0.06823920
# Validation score: 0.973108
# Iteration 30, loss = 0.06759739
# Validation score: 0.972483
# Iteration 31, loss = 0.06515063
# Validation score: 0.973108
# Iteration 32, loss = 0.06382386
# Validation score: 0.971232
# Iteration 33, loss = 0.06290307
# Validation score: 0.974984
# Iteration 34, loss = 0.06213055
# Validation score: 0.973734
# Iteration 35, loss = 0.06084723
# Validation score: 0.970607
# Iteration 36, loss = 0.05882415
# Validation score: 0.975610
# Iteration 37, loss = 0.05766530
# Validation score: 0.970607
# Iteration 38, loss = 0.05748037
# Validation score: 0.973108
# Iteration 39, loss = 0.05607207
# Validation score: 0.977486
# Iteration 40, loss = 0.05489890
# Validation score: 0.976861
# Iteration 41, loss = 0.05430749
# Validation score: 0.974359
# Iteration 42, loss = 0.05290015
# Validation score: 0.977486
# Iteration 43, loss = 0.05237752
# Validation score: 0.977486
# Iteration 44, loss = 0.05103128
# Validation score: 0.976861
# Iteration 45, loss = 0.05086867
# Validation score: 0.974984
# Iteration 46, loss = 0.04886596
# Validation score: 0.978737
# Iteration 47, loss = 0.04857310
# Validation score: 0.980613
# Iteration 48, loss = 0.04646183
# Validation score: 0.974359
# Iteration 49, loss = 0.04636837
# Validation score: 0.979362
# Iteration 50, loss = 0.04534312
# Validation score: 0.981864
# Iteration 51, loss = 0.04432143
# Validation score: 0.978737
# Iteration 52, loss = 0.04400310
# Validation score: 0.979362
# Iteration 53, loss = 0.04302869
# Validation score: 0.980613
# Iteration 54, loss = 0.04250879
# Validation score: 0.980613
# Iteration 55, loss = 0.04254554
# Validation score: 0.979987
# Iteration 56, loss = 0.04121569
# Validation score: 0.976861
# Iteration 57, loss = 0.04041986
# Validation score: 0.975610
# Iteration 58, loss = 0.03949396
# Validation score: 0.980613
# Iteration 59, loss = 0.03907274
# Validation score: 0.976861
# Iteration 60, loss = 0.03905966
# Validation score: 0.976235
# Iteration 61, loss = 0.03850542
# Validation score: 0.978737
# Validation score did not improve more than tol=0.000010 for 10 consecutive epochs. Stopping.
# MLPClassifier(early_stopping=True, hidden_layer_sizes=(60, 30),
#               learning_rate='adaptive', random_state=18, tol=1e-05,
#               verbose=True)

# %%
y_pred = mlp.predict(X_test)

# %%
metrics_mlp = PerformanceMetrics(y_test, y_pred)
metrics_mlp.report()
# Out:
# {'Accuracy': '0.979',
#  'Precision': '0.963',
#  'Recall': '0.961',
#  'F1 Score': '0.962'}

# %%
train_acc = mlp.score(X_train, y_train)
test_acc = mlp.score(X_test, y_test)

print("Train accuracy:", train_acc)
print("Test accuracy:", test_acc)
# Out:
# Train accuracy: 0.9856713803028407
# Test accuracy: 0.9791579824927052
