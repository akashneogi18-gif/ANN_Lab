# %%
import pandas as pd, numpy as np
df = pd.read_csv('hr_processed.csv')
df.sample(5)
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# 1743           -2.155721         1.089000        2.748604
# 9991            1.245922        -1.346611        0.169489
# 3614           -0.454900         1.207811       -0.690216
# 6645           -0.081548         0.613759       -0.690216
# 7962            0.706637         0.316733        1.029194
#
#       average_monthly_hours  time_spend_company  Work_accident  left  \
# 1743               0.913818                 1.0              0     1
# 9991               1.119048                -1.0              0     0
# 3614              -1.035869                -1.0              1     0
# 6645               0.174989                -1.0              0     0
# 7962               1.139571                -1.0              0     0
#
#       promotion_last_5years  salary  5year_experience  ...  sales_IT  \
# 1743                      0     1.0                 0  ...       0.0
# ...

# %%
df['left'].value_counts()
# Out:
# left
# 0    10000
# 1     1991
# Name: count, dtype: int64

# %% [markdown]
# - dataset is imbalanced

# %%
X = df.drop('left', axis=1).values
y = df['left'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=18)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=18)
X_train, y_train = sm.fit_resample(X_train, y_train)
# Out:
# C:\Users\Akash\anaconda3\envs\myenv\Lib\site-packages\joblib\externals\loky\backend\context.py:150: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\Akash\anaconda3\envs\myenv\Lib\site-packages\joblib\externals\loky\backend\context.py", line 227, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\Akash\anaconda3\envs\myenv\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Akash\anaconda3\envs\myenv\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
# ...

# %%
pd.Series(y_train).value_counts()
# Out:
# 0    7991
# 1    7991
# Name: count, dtype: int64

# %% [markdown]
# - small dataset(<5k) : tolerance 0.0001
# - medium dataset(~12k) : tolerance 0.0001 or 0.00001
# - large dataset(>100k) : tolerance 0.001

# %%
import nbimporter
from PerformanceMetrics import PerformanceMetrics

# %%
df.shape
# Out:
# (11991, 29)

# %% [markdown]
# - `class sklearn.neural_network.MLPClassifier(hidden_layer_sizes=(100,), activation='relu', *, solver='adam', alpha=0.0001, batch_size='auto', learning_rate='constant', learning_rate_init=0.001, power_t=0.5, max_iter=200, shuffle=True, random_state=None, tol=0.0001, verbose=False, warm_start=False, momentum=0.9, nesterovs_momentum=True, early_stopping=False, validation_fraction=0.1, beta_1=0.9, beta_2=0.999, epsilon=1e-08, n_iter_no_change=10, max_fun=15000)`

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=(10), activation='relu', solver='adam', learning_rate='adaptive',
                    learning_rate_init=0.001, max_iter=200, random_state=18, tol=0.00001,
                    verbose=True, early_stopping=True, validation_fraction=0.1)

# %%
mlp.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 0.69312501
# Validation score: 0.749844
# Iteration 2, loss = 0.56100012
# Validation score: 0.904941
# Iteration 3, loss = 0.41570896
# Validation score: 0.918074
# Iteration 4, loss = 0.32516265
# Validation score: 0.927455
# Iteration 5, loss = 0.28347678
# Validation score: 0.933083
# Iteration 6, loss = 0.26020008
# Validation score: 0.938712
# Iteration 7, loss = 0.24411667
# Validation score: 0.940588
# Iteration 8, loss = 0.23147624
# Validation score: 0.941839
# Iteration 9, loss = 0.22142028
# Validation score: 0.942464
# Iteration 10, loss = 0.21278307
# Validation score: 0.945591
# Iteration 11, loss = 0.20551234
# Validation score: 0.941213
# Iteration 12, loss = 0.19928919
# Validation score: 0.941839
# Iteration 13, loss = 0.19339912
# Validation score: 0.948093
# Iteration 14, loss = 0.18820733
# Validation score: 0.946216
# Iteration 15, loss = 0.18347877
# Validation score: 0.944966
# Iteration 16, loss = 0.17916783
# Validation score: 0.944966
# ...

# %%
y_pred = mlp.predict(X_test)

# %%
metrics_mlp = PerformanceMetrics(y_test, y_pred)
metrics_mlp.report()
# Out:
# {'Accuracy': '0.960',
#  'Precision': '0.910',
#  'Recall': '0.952',
#  'F1 Score': '0.931'}

# %%
train_acc = mlp.score(X_train, y_train)
test_acc = mlp.score(X_test, y_test)

print("Train accuracy:", train_acc)
print("Test accuracy:", test_acc)
# Out:
# Train accuracy: 0.9628957577274434
# Test accuracy: 0.9595664860358483
