# %%
import pandas as pd, numpy as np
df = pd.read_csv('hr_processed.csv')
df.sample(5)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 4666             0.084385        -1.406016       -0.690216
# 2543            -1.367536        -2.059473        1.888899
# 1670            -0.994185        -1.049585       -1.549921
# 11763            0.872571        -1.287206        0.169489
# 1583            -2.197205         0.554354        1.888899
#
#        average_monthly_hours  time_spend_company  Work_accident  left  \
# 4666               -1.425806                 0.0              1     0
# 2543                1.591077                 0.0              0     0
# 1670               -1.056392                 0.0              0     1
# 11763              -0.461224                -1.0              0     0
# 1583                2.206768                 1.0              0     1
#
#        promotion_last_5years  salary  5year_experience  ...  sales_IT  \
# 4666                       0     1.0                 0  ...       0.0
# ...
