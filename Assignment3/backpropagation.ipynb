# %%
import pandas as pd, numpy as np
df = pd.read_csv('hr_processed.csv')
df.sample(5)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 11180           -0.620833        -0.277318       -0.690216
# 11132            0.997021        -0.990180        0.169489
# 1291             0.374770         1.683052       -1.549921
# 5719             0.416253        -1.584232        1.029194
# 3939             0.540703        -1.643637        0.169489
#
#        average_monthly_hours  time_spend_company  Work_accident  left  \
# 11180              -0.358609                -1.0              0     0
# 11132              -0.071287                 0.0              0     0
# 1291                0.811203                -1.0              0     1
# 5719                0.647018                 1.0              0     0
# 3939               -0.173902                 1.0              1     0
#
#        promotion_last_5years  salary  5year_experience  ...  sales_IT  \
# 11180                      0     0.0                 0  ...       0.0
# 11132                      0     2.0                 0  ...       0.0
# 1291                       0     0.0                 0  ...       0.0
# 5719                       0     0.0                 0  ...       0.0
# 3939                       0     0.0                 0  ...       0.0
#
#        sales_RandD  sales_accounting  sales_hr  sales_management  \
# 11180          0.0               0.0       0.0               0.0
# 11132          0.0               0.0       0.0               0.0
# 1291           1.0               0.0       0.0               0.0
# 5719           0.0               1.0       0.0               0.0
# 3939           0.0               0.0       0.0               0.0
#
#        sales_marketing  sales_product_mng  sales_sales  sales_support  \
# 11180              0.0                0.0          0.0            0.0
# 11132              0.0                0.0          0.0            0.0
# 1291               0.0                0.0          0.0            0.0
# 5719               0.0                0.0          0.0            0.0
# 3939               0.0                0.0          0.0            0.0
#
#        sales_technical
# 11180              1.0
# 11132              1.0
# 1291               0.0
# 5719               0.0
# 3939               1.0
#
# [5 rows x 29 columns]

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (3.12.0)
# Requirement already satisfied: absl-py in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from keras) (2.3.1)
# Requirement already satisfied: numpy in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from keras) (2.0.1)
# Requirement already satisfied: rich in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from keras) (14.1.0)
# Requirement already satisfied: namex in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from keras) (3.15.1)
# Requirement already satisfied: optree in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from keras) (0.18.0)
# Requirement already satisfied: ml-dtypes in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from keras) (0.5.4)
# Requirement already satisfied: packaging in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from keras) (25.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from optree->keras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from rich->keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from rich->keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (6.33.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (78.1.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (3.12.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.10)
# Requirement already satisfied: pillow in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (11.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from keras>=3.10.0->tensorflow) (14.1.0)
# Requirement already satisfied: namex in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\akash\anaconda3\envs\myenv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)

# %%
X = df.drop(['left'], axis=1).values
y = df['left'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=18)

# %%
from keras import models, layers, optimizers, regularizers

# %%
model = models.Sequential()
model.add(layers.Dense(input_dim=len(X[0]),
                       units = 10,
                       activation = 'relu'))
model.add(layers.Dense(input_dim=10,
                       units = 1,
                       activation = 'sigmoid'))
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(learning_rate=0.01),
              metrics=['accuracy'])
# Out:
# C:\Users\Akash\anaconda3\envs\myenv\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from sklearn.metrics import accuracy_score
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
history = model.fit(X_train, y_train, epochs=10, batch_size=16)
train_acc = model.evaluate(X_train, y_train, batch_size=32)[1]
test_acc = model.evaluate(X_test, y_test, batch_size=32)[1]
print(f'Training accuracy {train_acc}')
print(f'Testing accuracy {test_acc}')
losses = history.history['loss']
plt.plot(range(len(losses)), losses, 'r')
plt.show()
# Out:
# Epoch 1/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9494 - loss: 0.1526
# Epoch 2/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9733 - loss: 0.0993
# Epoch 3/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9759 - loss: 0.0963
# Epoch 4/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9765 - loss: 0.0923
# Epoch 5/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9774 - loss: 0.0896
# Epoch 6/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9761 - loss: 0.0909
# Epoch 7/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9769 - loss: 0.0895
# Epoch 8/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9773 - loss: 0.0867
# Epoch 9/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9772 - loss: 0.0874
# Epoch 10/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9774 - loss: 0.0865
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9788 - loss: 0.0831
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9783 - loss: 0.0945
# Training accuracy 0.9788365364074707
# Testing accuracy 0.978324294090271
